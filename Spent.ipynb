# %% [markdown]
# # Analyis of Spent
# ## Survey Data
# 1. Food & Beverage Spent
# 2. Leisure & Entertainment Spent

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import IPython.core.display as di
# This line will hide code by default when the notebook is exported as HTML
di.display_html('<script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>', raw=True)
# Out:
# <script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>

# %%
data=pd.read_excel('RW1.xlsx')

# %% [markdown]
# # Histogram and Kernel Density Estimate Plot of
# ### 1. Income
# ### 2. F&B Spent and
# ### 3. L&E Spent

# %%
data2=data1.dropna(subset =['L&E']);

fig, ax = plt.subplots()
# the size of A4 paper
fig.set_size_inches(14, 6)

plt.subplot(1,3,1)
sns.distplot(data1['Inc_N'],color='black');

plt.subplot(1,3,2)
sns.distplot(data1['F&B'],color='red');

plt.subplot(1,3,3)
sns.distplot(data2['L&E'],color='b');

# %% [markdown]
# ANALYSIS
# 1. Income is normally distributed
# 2. F&B is skewed right with most people spending between 500 - 1500 SAR
# 3. L&E is almost normal with most people spending between 600-700 SAR

# %% [markdown]
# # Pairwise relationship Plot of Income, Age & Spent

# %%
data3=data.dropna()

# %%
 g= sns.pairplot(data3, kind='reg');

# %%
data3.corr()
# Out:
#                L&E       F&B  Income_N     Age_N
# L&E       1.000000  0.333283  0.397231  0.329822
# F&B       0.333283  1.000000  0.023142  0.091066
# Income_N  0.397231  0.023142  1.000000  0.331495
# Age_N     0.329822  0.091066  0.331495  1.000000

# %% [markdown]
# ANALYSIS
# 1. Leisure and Entertainemnt Spent shows slight positive correlation with Income and Age
# 2. Food and Beverages spent shows no correlation with Income and Age

# %% [markdown]
# ## Spent on Leisure & Entertainment by type of Residential Unit (Apartment, Villa) and  Rent or Own

# %%
sns.set_style('ticks')
fig, ax = plt.subplots()
# the size of A4 paper
fig.set_size_inches(9, 6)
sns.boxplot(x="Own or Rent", y="L&E", hue="Type of residential unit", data=data,palette='rainbow');

# %% [markdown]
# ANALYSIS
#
# 1. Owners of Apartment spent more on L&E compared to owners of Villa

# %% [markdown]
# ## Spent on F&B by type of Residential Unit (Apartment, Villa) and  Rent or Own

# %%
fig, ax = plt.subplots()
# the size of A4 paper
fig.set_size_inches(9, 6)
sns.boxplot(x="Own or Rent", y="F&B", hue="Type of residential unit", data=data,palette='rainbow');

# %% [markdown]
# ANALYSIS
#
# 1. People living in Apartments whether Rent or Own spent more on F&B compared to resisdent of Villas

# %%
data1=pd.read_excel('RW1.xlsx', sheetname='inc')

# %% [markdown]
# # F&B Spent w.r.t No of Family Members and Malls Visit Frequency

# %%
fig, ax = plt.subplots()
# the size of A4 paper
fig.set_size_inches(15, 7)
sns.boxplot(x="No of family members", y="F&B",hue="Visit",data=data,palette='RdBu_r',width=2);

# %% [markdown]
# ANALYSIS
#
# Families with 08 and 04 members who visit Malls Three times and Twice a Week spent most on F&B

# %% [markdown]
# # L&E Spent w.r.t No of Family Members and Malls Visit Frequency

# %%
fig, ax = plt.subplots()
# the size of A4 paper
fig.set_size_inches(15, 7)
sns.boxplot(x="No of family members", y="L&E",hue="Visit",data=data,palette='RdBu_r',width=2);

# %% [markdown]
# ANALYSIS
#
# Families with 07 and 08 members who visit Malls Once a week spent most on L&E

# %% [markdown]
# # Pair Grid Plot of F&B, L&E Spent & Income. Age categories shown by color

# %%
data4=data=pd.read_excel('RW1.xlsx', sheetname='Sheet3')

# %%
>>> g = sns.PairGrid(data4, hue="Age", palette="Set2");
>>> g = g.map_diag(plt.hist, linewidth=2)
>>> g = g.map_offdiag(plt.scatter)
>>> g = g.add_legend()

# %% [markdown]
# ANALYSIS
# 1. Age Group 35-44 Spent more on Leisure and Entertainment Activities. The spent increase with Income
#
# 2. Age Group 25-29 and 35-39 Spent more on Food and Beverages with no correlation with increase in income

# %%
data4.corr()
# Out:
#                L&E       F&B  Income_N
# L&E       1.000000  0.294116  0.423608
# F&B       0.294116  1.000000  0.004563
# Income_N  0.423608  0.004563  1.000000
